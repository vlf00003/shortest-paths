# %% [markdown]
# <a href="https://colab.research.google.com/github/vlf00003/shortest-paths/blob/master/draft_2023_Spring_Assignment_M6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
# #University of Stirling - Spring 2023
#
# ## CSCU9M6 - Natural Language Processing and Computer Vision (2022/3)
#
# ---

# %% [markdown]
# # Assignment Summary
#
# In this activity, you are required to apply the knowledge acquired in this module through the design and development of a complete project for image classification in an application to be defined by yourself. For this, you will need to perform the following **mandatory** steps:
#
# 1. [Problem definition](#scrollTo=hglJVRRslqMn)
# 2. [GitHub repository](#scrollTo=ecxDhkV9qmUf)
# 3. [Dataset](#scrollTo=qEgFzxmWrGA9)
# 4. [Dataloader](#scrollTo=EDd6lLwlx4un)
# 5. [Proposed solution](#scrollTo=ScTrpUW8zOp4)
# 6. [Experimental tests and evaluations](#scrollTo=3RBW58of0ZDo)
# 7. [Quiz and Report](#scrollTo=ws14iV4Dp_vf)
#
# **Deadlines** and other details can be seen on Canvas [\[link\]](https://canvas.stir.ac.uk/courses/12587/assignments/102373).

# %% [markdown]
# ---
#
# # 1. **Problem definition**
#
#
# In this assignment, you are required to apply the knowledge acquired in the module to solve a classification problem from images collected in the context of two different cities (A and B).
#  - If the work is being carried out in pairs, **cities A and B must be the hometowns of each student**. In the case of individual work, city A must be your hometown and city B must be Stirling (or Edinburgh, if needed).
#  - The standard recommendation is that the project focuses on classifying cars or trees image scenes, which are easier to identify and annotate. Other objects or phenomena can be adopted, but are subject to prior approval by the module instructor (Jefersson A. dos Santos). **You are not allowed to assemble datasets containing people. Other sensitive patterns, such as license plates, must be properly hidden.**
#  - Don't panic! We are aware that acquiring images _in situ_ is an impediment for most students. The dataset can be assembled with images collected remotely or from public repositories. Just be careful with rights and permissions for using images found on the internet. Anyway, these factors must be taken into account for the problem definition.
#  - While we encourage you to do interesting and engaging work, it shouldn't be too complex or time-consuming. Try to appropriately scale the time required for this step. Ask the instructors for advice, if necessary. **GA students:** you are encouraged to link the project with your work activities, but keep in mind you still need to construct two datasets (A and B).
#
# [top](#scrollTo=4i5afvUbhmGo)

# %% [markdown]
# ---
# # 2. **GitHub repository**
#
# Give your project a name, create a private [GitHub repository](https://github.com/) with the name [Module Code] + [Project Name] and give access to the module instructors. Create a cover page with a description of your project. This empty notebook must be uploaded in the repository as well as the created dataset. The deadline to perform this task will be 10 days after the publication of this notebook.
# This notebook should be updated and committed to the repository according to the deadlines.
# The repository's update history will be used as a criterion for monitoring and evaluating the work.
# **Check the videos provided in the extra section on Canvas for more details on how to create your GitHub repository** [\[link\]](https://canvas.stir.ac.uk/courses/12587/pages/extra-session-cnn-hyperparameters-and-github).
#
# [top](#scrollTo=4i5afvUbhmGo)

# %% [markdown]
# ---
# # 3. **Dataset creation**
#
# You must collect a minimum of **200 positive samples** from the study objects for each city (A and B).
# Note that, depending on the task being solved, it will also be necessary to collect more samples - negative ones, for instance.
#
# Your dataset can be assembled from one or more of the following ways:
#
#   - *M1* - Pictures taken by yourself on site (street view from cities A and B), with attention to anonymization issues (if it is the case). It is not allowed to assemble datasets containing people. Other sensitive patterns, such as license plates, must be properly hidden.
#
#   - *M2* - Aerial satellite/drone images obtained from GIS and remote sensing platforms or public repositories. Be careful with unusual file formats that may be challenging to manipulate using basic image processing libraries. We recommend keeping or converting the images to jpg or png.
#
#   - *M3* - Pictures taken from other public available datasets. Remember you are not allowed to use datasets containing people or other sensitive patterns/objects.
#
#   - *M4* - Images crawled from the internet as a whole (social networks, webpages, etc), with special attention to use and copyrights.
#
#   - *M5* - Textual and metadata you may need in your project, with special attention to use and copyrights (as always!).
#
# **Important:** If you collect the images on your own or from aerial imagery repositories, it will be necessary to keep the geographic coordinates. If you collect from specific websites, please retain the source links. This information should be placed in a .csv file and made available along with the final dataset.
#
# [top](#scrollTo=4i5afvUbhmGo)

# %% [markdown]
# ---
#
# # 4. **Dataloader**
#
# Here you are required to implement all the code related to pre-processing, cleaning, de-noising and preparing the input images and metadata according to the necessary data structures as input to your pattern recognition module. We recommend using [PyTorch](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html) or [Tensorflow (with Keras)](https://keras.io/getting_started/intro_to_keras_for_engineers/) as a base, but you are free to use any library or platform as long as it is well justified in the [final report](#scrollTo=ws14iV4Dp_vf).
#
# [top](scrollTo=4i5afvUbhmGo)

# %%
# Write your dataloader code here. Create more code cells if you find it necessary

import time, os, sys, numpy as np
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F

from torch import optim
from torchsummary import summary
from torchvision.transforms import transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor

import time, os, sys, numpy as np

# Test if GPU is avaliable, if not, use cpu instead
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
n = torch.cuda.device_count()
devices_ids= list(range(n))
print(device)

# Downloading and unzipping the dataset.
# Write your dataloader code here. Create more code cells if you find it necessary
# !wget https://www.dropbox.com/s/kwyarrvmgnn1b6g/cars.zip
# !unzip cars.zip
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# cpu
# --2023-03-25 16:04:09--  https://www.dropbox.com/s/kwyarrvmgnn1b6g/cars.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/kwyarrvmgnn1b6g/cars.zip [following]
# --2023-03-25 16:04:10--  https://www.dropbox.com/s/raw/kwyarrvmgnn1b6g/cars.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc1f0ca2ce42e09d94bcf0e3e70.dl.dropboxusercontent.com/cd/0/inline/B45Smtp1c8FSuEIGhsbbUF2uPOoc2yOjP8iXMZwz7IeMdyD1EREFI-kPbCthU0bCYjoexZpgcRMa94xo4IMkY_YEwnzWeSKu84deq6h5c0AdonFQJ8DqP8rSAvC6hcXfZ7HvWfP__J-mgcCbQcuuOkopB3KbkPeT7UxPHqupG6B3TA/file# [following]
# --2023-03-25 16:04:11--  https://ucc1f0ca2ce42e09d94bcf0e3e70.dl.dropboxusercontent.com/cd/0/inline/B45Smtp1c8FSuEIGhsbbUF2uPOoc2yOjP8iXMZwz7IeMdyD1EREFI-kPbCthU0bCYjoexZpgcRMa94xo4IMkY_YEwnzWeSKu84deq6h5c0AdonFQJ8DqP8rSAvC6hcXfZ7HvWfP__J-mgcCbQcuuOkopB3KbkPeT7UxPHqupG6B3TA/file
# Resolving ucc1f0ca2ce42e09d94bcf0e3e70.dl.dropboxusercontent.com (ucc1f0ca2ce42e09d94bcf0e3e70.dl.dropboxusercontent.com)... 162.125.7.15, 2620:100:6027:15::a27d:480f
# Connecting to ucc1f0ca2ce42e09d94bcf0e3e70.dl.dropboxusercontent.com (ucc1f0ca2ce42e09d94bcf0e3e70.dl.dropboxusercontent.com)|162.125.7.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2
#   inflating: cars/cars_stirling/test/0/Capture.PNG
#   inflating: cars/cars_stirling/test/0/cvba.PNG
#   inflating: cars/cars_stirling/test/0/cvbaa.PNG
#   inflating: cars/cars_stirling/test/0/cvx.PNG
#   inflating: cars/cars_stirling/test/0/cxvag.PNG
#   inflating: cars/cars_stirling/test/0/sadvc.PNG
#   inflating: cars/cars_stirling/test/0/sadxc.PNG
#   inflating: cars/cars_stirling/test/0/xcvxa.PNG
#   inflating: cars/cars_stirling/test/0/xx.PNG
#   inflating: cars/cars_stirling/test/0/xxa.PNG
#   inflating: cars/cars_stirling/test/0/xxx.PNG
#   inflating: cars/cars_stirling/test/0/xxxx.PNG
#   inflating: cars/cars_stirling/test/0/xzcaxcv.PNG
#   inflating: cars/cars_stirling/test/0/zxca.PNG
#   inflating: cars/cars_stirling/test/0/zxcag.PNG
#    creating: cars/cars_stirling/test/1/
#   inflating: cars/cars_stirling/test/1/asd.PNG
#   inflating: cars/cars_stirling/test/1/b.PNG
#   inflating: cars/cars_stirling/test/1/bbb.PNG
#   inflating: cars/cars_stirling/test/1/bvc.PNG
#   inflating: cars/cars_stirling/test/1/cvbc.PNG
#   inflating: cars/cars_stirling/test/1/cxv.PNG
#   inflating: cars/cars_stirling/test/1/f.PNG
#   inflating: cars/cars_stirling/test/1/gg.PNG
#   inflating: cars/cars_stirling/test/1/hgf.PNG
#   inflating: cars/cars_stirling/test/1/jjj.PNG
#   inflating: cars/cars_stirling/test/1/m.PNG
#   inflating: cars/cars_stirling/test/1/mbn.PNG
#   inflating: cars/cars_stirling/test/1/sda.PNG
#   inflating: cars/cars_stirling/test/1/sdagf.PNG
#   inflating: cars/cars_stirling/test/1/ss.PNG
#   inflating: cars/cars_stirling/test/1/ssd.PNG
#   inflating: cars/cars_stirling/test/1/ssda.PNG
#   inflating: cars/cars_stirling/test/1/ssdaaf.PNG
#   inflating: cars/cars_stirling/test/1/ssss.PNG
#   inflating: cars/cars_stirling/test/1/v.PNG
#   inflating: cars/cars_stirling/test/1/vbcv.PNG
#   inflating: cars/cars_stirling/test/1/vbnn.PNG
#   inflating: cars/cars_stirling/test/1/vc.PNG
#   inflating: cars/cars_stirling/test/1/vcbcvb.PNG
#   inflating: cars/cars_stirling/test/1/vcbcvbc.PNG
#   inflating: cars/cars_stirling/test/1/vcbdf.PNG
#   inflating: cars/cars_stirling/test/1/vcc.PNG
#   inflating: cars/cars_stirling/test/1/vccx.PNG
#   inflating: cars/cars_stirling/test/1/vcx.PNG
#   inflating: cars/cars_stirling/test/1/xasa.PNG
#   inflating: cars/cars_stirling/test/1/xc.PNG
#   inflating: cars/cars_stirling/test/1/xcvad.PNG
#   inflating: cars/cars_stirling/test/1/xcvxa.PNG
#   inflating: cars/cars_stirling/test/1/xcvxcd.PNG
#   inflating: cars/cars_stirling/test/1/xvca.PNG
#   inflating: cars/cars_stirling/test/1/xxx.PNG
#   inflating: cars/cars_stirling/test/1/xxxad.PNG
#   inflating: cars/cars_stirling/test/1/xxxx.PNG
#   inflating: cars/cars_stirling/test/1/xxxxxx.PNG
#   inflating: cars/cars_stirling/test/1/ytu.PNG
#    creating: cars/cars_stirling/train/
#    creating: cars/cars_stirling/train/0/
#   inflating: cars/cars_stirling/train/0/1234.PNG
#   inflating: cars/cars_stirling/train/0/352.PNG
#   inflating: cars/cars_stirling/train/0/3544.PNG
#   inflating: cars/cars_stirling/train/0/56445.PNG
#   inflating: cars/cars_stirling/train/0/634.PNG
#   inflating: cars/cars_stirling/train/0/cvbsa.PNG
#   inflating: cars/cars_stirling/train/0/cvxa.PNG
#   inflating: cars/cars_stirling/train/0/cxa.PNG
#   inflating: cars/cars_stirling/train/0/cxvxca.PNG
#   inflating: cars/cars_stirling/train/0/cxvxgf.PNG
#   inflating: cars/cars_stirling/train/0/dfgda.PNG
#   inflating: cars/cars_stirling/train/0/dfgdfg.PNG
#   inflating: cars/cars_stirling/train/0/dfsh.PNG
#   inflating: cars/cars_stirling/train/0/dfshds.PNG
#   inflating: cars/cars_stirling/train/0/kihjb.PNG
#   inflating: cars/cars_stirling/train/0/nbfd.PNG
#   inflating: cars/cars_stirling/train/0/okjni.PNG
#   inflating: cars/cars_stirling/train/0/sadas.PNG
#   inflating: cars/cars_stirling/train/0/vbcbc.PNG
#   inflating: cars/cars_stirling/train/0/xa.PNG
#   inflating: cars/cars_stirling/train/0/xcva.PNG
#   inflating: cars/cars_stirling/train/0/xcvafg.PNG
#   inflating: cars/cars_stirling/train/0/xcvag.PNG
#   inflating: cars/cars_stirling/train/0/xcvbna.PNG
#   inflating: cars/cars_stirling/train/0/xcvsa.PNG
#   inflating: cars/cars_stirling/train/0/xcvxc.PNG
#   inflating: cars/cars_stirling/train/0/xcza.PNG
#   inflating: cars/cars_stirling/train/0/xczaf.PNG
#   inflating: cars/cars_stirling/train/0/xczcz.PNG
#   inflating: cars/cars_stirling/train/0/xzca.PNG
#    creating: cars/cars_stirling/train/1/
#   inflating: cars/cars_stirling/train/1/cxvasd.PNG
#   inflating: cars/cars_stirling/train/1/cxvassd.PNG
#   inflating: cars/cars_stirling/train/1/cxvx.PNG
#   inflating: cars/cars_stirling/train/1/cxvxcv.PNG
#   inflating: cars/cars_stirling/train/1/cxvxx.PNG
#   inflating: cars/cars_stirling/train/1/ddd.PNG
#   inflating: cars/cars_stirling/train/1/ddfasd.PNG
#   inflating: cars/cars_stirling/train/1/dfcxv.PNG
#   inflating: cars/cars_stirling/train/1/dfds.PNG
#   inflating: cars/cars_stirling/train/1/dfgdfa.PNG
#   inflating: cars/cars_stirling/train/1/dfgdfg.PNG
#   inflating: cars/cars_stirling/train/1/dfsa.PNG
#   inflating: cars/cars_stirling/train/1/dfsd.PNG
#   inflating: cars/cars_stirling/train/1/dgdf.PNG
#   inflating: cars/cars_stirling/train/1/dgs.PNG
#   inflating: cars/cars_stirling/train/1/dsfaaa.PNG
#   inflating: cars/cars_stirling/train/1/dsfdscv.PNG
#   inflating: cars/cars_stirling/train/1/dsfsdf.PNG
#   inflating: cars/cars_stirling/train/1/dsvc.PNG
#   inflating: cars/cars_stirling/train/1/esdf.PNG
#   inflating: cars/cars_stirling/train/1/vcbcvb.PNG
#   inflating: cars/cars_stirling/train/1/vcccc.PNG
#   inflating: cars/cars_stirling/train/1/vcdf.PNG
#   inflating: cars/cars_stirling/train/1/vchncv.PNG
#   inflating: cars/cars_stirling/train/1/vcxx.PNG
#   inflating: cars/cars_stirling/train/1/vnbnvbn.PNG
#   inflating: cars/cars_stirling/train/1/vnbv.PNG
#   inflating: cars/cars_stirling/train/1/vv.PNG
#   inflating: cars/cars_stirling/train/1/vvv.PNG
#   inflating: cars/cars_stirling/train/1/vvvv.PNG
#   inflating: cars/cars_stirling/train/1/w.PNG
#   inflating: cars/cars_stirling/train/1/wqe.PNG
#   inflating: cars/cars_stirling/train/1/xcva.PNG
#   inflating: cars/cars_stirling/train/1/xcvhdy.PNG
#   inflating: cars/cars_stirling/train/1/xcvxb.PNG
#   inflating: cars/cars_stirling/train/1/xcvxcf.PNG
#   inflating: cars/cars_stirling/train/1/xcvxdf.PNG
#   inflating: cars/cars_stirling/train/1/xcvxs.PNG
#   inflating: cars/cars_stirling/train/1/xcx.PNG
#   inflating: cars/cars_stirling/train/1/xcz.PNG
#   inflating: cars/cars_stirling/train/1/xczxz.PNG
#   inflating: cars/cars_stirling/train/1/xczzxc.PNG
#   inflating: cars/cars_stirling/train/1/xx.PNG
#   inflating: cars/cars_stirling/train/1/xxvx.PNG
#   inflating: cars/cars_stirling/train/1/xxxxx.PNG
#   inflating: cars/cars_stirling/train/1/xz.PNG
#   inflating: cars/cars_stirling/train/1/xza.PNG
#   inflating: cars/cars_stirling/train/1/xzadf.PNG
#   inflating: cars/cars_stirling/train/1/xzca.PNG
#   inflating: cars/cars_stirling/train/1/zxc.PNG
#   inflating: cars/cars_stirling/train/1/zxcz.PNG
#   inflating: cars/cars_stirling/train/1/сс.PNG
#    creating: cars/cars_tallinn/
#    creating: cars/cars_tallinn/test/
#    creating: cars/cars_tallinn/test/0/
#   inflating: cars/cars_tallinn/test/0/124.PNG
#   inflating: cars/cars_tallinn/test/0/45r.PNG
#   inflating: cars/cars_tallinn/test/0/543.PNG
#   inflating: cars/cars_tallinn/test/0/5436.PNG
#   inflating: cars/cars_tallinn/test/0/564.PNG
#   inflating: cars/cars_tallinn/test/0/5643.PNG
#   inflating: cars/cars_tallinn/test/0/576.PNG
#   inflating: cars/cars_tallinn/test/0/6435.PNG
#   inflating: cars/cars_tallinn/test/0/647.PNG
#   inflating: cars/cars_tallinn/test/0/657.PNG
#   inflating: cars/cars_tallinn/test/0/75464.PNG
#   inflating: cars/cars_tallinn/test/0/756.PNG
#   inflating: cars/cars_tallinn/test/0/765.PNG
#   inflating: cars/cars_tallinn/test/0/7687.PNG
#   inflating: cars/cars_tallinn/test/0/7868.PNG
#   inflating: cars/cars_tallinn/test/0/8768.PNG
#   inflating: cars/cars_tallinn/test/0/878.PNG
#   inflating: cars/cars_tallinn/test/0/asdx.PNG
#   inflating: cars/cars_tallinn/test/0/Capture.PNG
#   inflating: cars/cars_tallinn/test/0/cvbba.PNG
#   inflating: cars/cars_tallinn/train/0/123.PNG
#   inflating: cars/cars_tallinn/train/0/12354.PNG
#   inflating: cars/cars_tallinn/train/0/234.PNG
#   inflating: cars/cars_tallinn/train/0/345.PNG
#   inflating: cars/cars_tallinn/train/0/35324.PNG
#   inflating: cars/cars_tallinn/train/0/4323.PNG
#   inflating: cars/cars_tallinn/train/0/43534.PNG
#   inflating: cars/cars_tallinn/train/0/532.PNG
#   inflating: cars/cars_tallinn/train/0/76.PNG
#   inflating: cars/cars_tallinn/train/0/asdcv.PNG
#   inflating: cars/cars_tallinn/train/0/asdfg.PNG
#   inflating: cars/cars_tallinn/train/0/asdgx.PNG
#   inflating: cars/cars_tallinn/train/0/asdxcv.PNG
#   inflating: cars/cars_tallinn/train/0/bcvba.PNG
#   inflating: cars/cars_tallinn/train/0/bvc.PNG
#   inflating: cars/cars_tallinn/train/0/cvba.PNG
#   inflating: cars/cars_tallinn/train/0/cvc.PNG
#   inflating: cars/cars_tallinn/train/0/cvx.PNG
#   inflating: cars/cars_tallinn/train/0/cxvag.PNG
#   inflating: cars/cars_tallinn/train/0/nbmb.PNG
#   inflating: cars/cars_tallinn/train/0/sadcvx.PNG
#   inflating: cars/cars_tallinn/train/0/sdfcxv.PNG
#   inflating: cars/cars_tallinn/train/0/sdfgcv.PNG
#   inflating: cars/cars_tallinn/train/0/vcb.PNG
#   inflating: cars/cars_tallinn/train/0/vgb.PNG
#   inflating: cars/cars_tallinn/train/0/xcvag.PNG
#   inflating: cars/cars_tallinn/train/0/xcvagg.PNG
#   inflating: cars/cars_tallinn/train/0/xcvga.PNG
#   inflating: cars/cars_tallinn/train/0/xcvxa.PNG
#   inflating: cars/cars_tallinn/train/0/xczza.PNG
#    creating: cars/cars_tallinn/train/1/
#   inflating: cars/cars_tallinn/train/1/231321.PNG
#   inflating: cars/cars_tallinn/train/1/23567.PNG
#   inflating: cars/cars_tallinn/train/1/324235.PNG
#   inflating: cars/cars_tallinn/train/1/34567.PNG
#   inflating: cars/cars_tallinn/train/1/45321.PNG
#   inflating: cars/cars_tallinn/train/1/453634.PNG
#   inflating: cars/cars_tallinn/train/1/45675.PNG
#   inflating: cars/cars_tallinn/train/1/45678.PNG
#   inflating: cars/cars_tallinn/train/1/46732.PNG
#   inflating: cars/cars_tallinn/train/1/54356.PNG
#   inflating: cars/cars_tallinn/train/1/556754.PNG
#   inflating: cars/cars_tallinn/train/1/56432.PNG
#   inflating: cars/cars_tallinn/train/1/56435.PNG
#   inflating: cars/cars_tallinn/train/1/6575568.PNG
#   inflating: cars/cars_tallinn/train/1/65767.PNG
#   inflating: cars/cars_tallinn/train/1/67576.PNG
#   inflating: cars/cars_tallinn/train/1/67586.PNG
#   inflating: cars/cars_tallinn/train/1/745456.PNG
#   inflating: cars/cars_tallinn/train/1/75678.PNG
#   inflating: cars/cars_tallinn/train/1/86745.PNG
#   inflating: cars/cars_tallinn/train/1/89645.PNG
#   inflating: cars/cars_tallinn/train/1/98789.PNG
#   inflating: cars/cars_tallinn/train/1/a.PNG
#   inflating: cars/cars_tallinn/train/1/aa.PNG
#   inflating: cars/cars_tallinn/train/1/acxz.PNG
#   inflating: cars/cars_tallinn/train/1/adsad.PNG
#   inflating: cars/cars_tallinn/train/1/as.PNG
#   inflating: cars/cars_tallinn/train/1/asd.PNG
#   inflating: cars/cars_tallinn/train/1/asdafg.PNG
#   inflating: cars/cars_tallinn/train/1/asdcc.PNG
#   inflating: cars/cars_tallinn/train/1/asdf.PNG
#   inflating: cars/cars_tallinn/train/1/asdfg.PNG
#   inflating: cars/cars_tallinn/train/1/asdfga.PNG
#   inflating: cars/cars_tallinn/train/1/asdga.PNG
#   inflating: cars/cars_tallinn/train/1/asdgfa.PNG
#   inflating: cars/cars_tallinn/train/1/asdx.PNG
#   inflating: cars/cars_tallinn/train/1/b.PNG
#   inflating: cars/cars_tallinn/train/1/bbb.PNG
#   inflating: cars/cars_tallinn/train/1/bbbvc.PNG
#   inflating: cars/cars_tallinn/train/1/bbc.PNG
#   inflating: cars/cars_tallinn/train/1/bccc.PNG
#   inflating: cars/cars_tallinn/train/1/bccxx.PNG
#   inflating: cars/cars_tallinn/train/1/bcvbc.PNG
#   inflating: cars/cars_tallinn/train/1/bcvbcv.PNG
#   inflating: cars/cars_tallinn/train/1/bcvcv.PNG
#   inflating: cars/cars_tallinn/train/1/bnbn.PNG
#   inflating: cars/cars_tallinn/train/1/bnbnb.PNG
#   inflating: cars/cars_tallinn/train/1/bnmb.PNG
#   inflating: cars/cars_tallinn/train/1/bnmbn.PNG
#   inflating: cars/cars_tallinn/train/1/bnmbnm.PNG
#   inflating: cars/cars_tallinn/train/1/bnv.PNG
#   inflating: cars/cars_tallinn/train/1/bnvb.PNG
#   inflating: cars/cars_tallinn/train/1/bnvc.PNG
#   inflating: cars/cars_tallinn/train/1/bnvn.PNG
#   inflating: cars/cars_tallinn/train/1/bvbc.PNG
#   inflating: cars/cars_tallinn/train/1/bvbv.PNG
#   inflating: cars/cars_tallinn/train/1/bvc.PNG
#   inflating: cars/cars_tallinn/train/1/bvcbcv.PNG
#   inflating: cars/cars_tallinn/train/1/bvcc.PNG
#   inflating: cars/cars_tallinn/train/1/bvccn.PNG
#   inflating: cars/cars_tallinn/train/1/bvnv.PNG
#   inflating: cars/cars_tallinn/train/1/bvsad.PNG
#   inflating: cars/cars_tallinn/train/1/bvvb.PNG
#   inflating: cars/cars_tallinn/train/1/bvxc.PNG
#   inflating: cars/cars_tallinn/train/1/c.PNG
#   inflating: cars/cars_tallinn/train/1/Capture.PNG
#   inflating: cars/cars_tallinn/train/1/Capture1.PNG
#   inflating: cars/cars_tallinn/train/1/Capture2.PNG
#   inflating: cars/cars_tallinn/train/1/Capture3.PNG
#   inflating: cars/cars_tallinn/train/1/cbvbcv.PNG
#   inflating: cars/cars_tallinn/train/1/ccc.PNG
#   inflating: cars/cars_tallinn/train/1/cccb.PNG
#   inflating: cars/cars_tallinn/train/1/cccbfd.PNG
#   inflating: cars/cars_tallinn/train/1/cccc.PNG
#   inflating: cars/cars_tallinn/train/1/ccvb.PNG
#   inflating: cars/cars_tallinn/train/1/ccx.PNG
#   inflating: cars/cars_tallinn/train/1/cfg.PNG
#   inflating: cars/cars_tallinn/train/1/cvb.PNG
#   inflating: cars/cars_tallinn/train/1/cvba.PNG
#   inflating: cars/cars_tallinn/train/1/cvbaaa.PNG
#   inflating: cars/cars_tallinn/train/1/cvbc.PNG
#   inflating: cars/cars_tallinn/train/1/cvbcss.PNG
#   inflating: cars/cars_tallinn/train/1/cvbcvb.PNG
#   inflating: cars/cars_tallinn/train/1/cvbcvbcvb.PNG
#   inflating: cars/cars_tallinn/train/1/cvbcvbfd.PNG
#   inflating: cars/cars_tallinn/train/1/cvbcvbn.PNG
#   inflating: cars/cars_tallinn/train/1/cvbcvbs.PNG
#   inflating: cars/cars_tallinn/train/1/cvbcvc.PNG
#   inflating: cars/cars_tallinn/train/1/cvbcvd.PNG
#   inflating: cars/cars_tallinn/train/1/cvbsd.PNG
#   inflating: cars/cars_tallinn/train/1/cvbxcvb.PNG
#   inflating: cars/cars_tallinn/train/1/cvcc.PNG
#   inflating: cars/cars_tallinn/train/1/cvnbn.PNG
#   inflating: cars/cars_tallinn/train/1/cvx.PNG
#   inflating: cars/cars_tallinn/train/1/cvxas.PNG
#   inflating: cars/cars_tallinn/train/1/cvxcvs.PNG
#   inflating: cars/cars_tallinn/train/1/cvxcvx.PNG
#   inflating: cars/cars_tallinn/train/1/cx.PNG
#   inflating: cars/cars_tallinn/train/1/cxv.PNG
#   inflating: cars/cars_tallinn/train/1/cxvas.PNG

# %%
#Transforms
def load_data(batch_size, resize):
  transformer=transforms.Compose([
      transforms.Resize((resize, resize)),
      transforms.RandomHorizontalFlip(),
      transforms.ToTensor(),  #0-255 to 0-1, numpy to tensors
      transforms.Normalize(mean=[0.5,0.5,0.5], # 0-1 to [-1,1] , formula (x-mean)/std
                          std=[0.5,0.5,0.5])
])
    #Dataloader
  #Path for training and testing directory
  train_path_tal= '/content/cars/cars_tallinn/train'
  test_path_tal = '/content/cars/cars_tallinn/test'
  train_path_stir= '/content/cars/cars_stirling/train'
  test_path_stir = '/content/cars/cars_stirling/test'

  train_loader_tal= DataLoader(torchvision.datasets.ImageFolder(root=train_path_tal,transform=transformer),
       batch_size, shuffle=True)
  test_loader_tal=DataLoader(torchvision.datasets.ImageFolder(root=test_path_tal,transform=transformer),
                         batch_size, shuffle=True)
  
  train_loader_stir= DataLoader(torchvision.datasets.ImageFolder(root=train_path_stir,transform=transformer),
       batch_size, shuffle=True)
  test_loader_stir=DataLoader(torchvision.datasets.ImageFolder(root=test_path_stir,transform=transformer),
                         batch_size, shuffle=True)
  
  return train_loader_tal, test_loader_tal, train_loader_stir, test_loader_stir

# %%
# !rm -rf `find -type d -name .ipynb_checkpoints`

# %% [markdown]
# ---
#
# # 5. **Proposed solution**
#
# This is where you should implement most of your code for your solution. Write the routines for training and predicting the models and any necessary intermediate steps. Post-processing functions must also be implemented here.
#
#   - Use good programming practices, modularizing and adequately commenting on your code. Code quality will be considered in the final assessment.
#
#   - You can use pre-trained models as backbones or any code available on the web as a basis, but they must be correctly credited and referenced both in this notebook and in the final report. Cite the source link repository and explicitly cite the authors of it.
# If you changed existing code, make it clear what the changes were.
# Make it clear where your own code starts and where it ends. Note that the originality percentage of the code will be considered in the evaluation, so use external codes wisely and sparingly. **Missconduct alert:** remember that there are many tools that compare existing source code and that it is relatively easy to identify authorship. So, be careful and fair by always properly thanking the authors if you use external code.
#
# [top](#scrollTo=4i5afvUbhmGo)

# %%
# Basic functions
def _get_batch(batch):
    """Return features and labels on ctx."""
    features, labels = batch
    if labels.type() != features.type():
        labels = labels.type(features.type())
    return (torch.nn.DataParallel(features, device_ids=devices_ids),
            torch.nn.DataParallel(labels, device_ids=devices_ids), features.shape[0])

# Function used to compute accuracy
def evaluate_accuracy(data_iter, net, loss):
    """Evaluate accuracy of a model on the given data set."""

    acc_sum, n, l = torch.Tensor([0]), 0, 0
    net.eval()
    with torch.no_grad():
      for X, y in data_iter:
          #y = y.astype('float32')
          X, y = X.to(device), y.to(device)
          y_hat = net(X)
          l += loss(y_hat, y).sum()
          acc_sum += (y_hat.argmax(axis=1) == y).sum().item()
          n += y.size()[0]

    return acc_sum.item() / n, l.item() / len(data_iter)
  
# Function used for training and network validation
def train_validate(net, train_iter, test_iter, batch_size, trainer, loss,
                   num_epochs, city):
    accuracy = []
    best_accuracy=0.0
    print('training on', device)
    for epoch in range(num_epochs):
        net.train()
        train_l_sum, train_acc_sum, n, start = 0.0, 0.0, 0, time.time()
        for X, y in train_iter:
            X, y = X.to(device), y.to(device)
            y_hat = net(X)
            trainer.zero_grad()
            l = loss(y_hat, y).sum()
            l.backward()
            trainer.step()
            train_l_sum += l.item()
            train_acc_sum += (y_hat.argmax(axis=1) == y).sum().item()
            n += y.size()[0]
        test_acc, test_loss = evaluate_accuracy(test_iter, net, loss)
        accuracy.append(train_acc_sum / n)
        print('epoch %d, train loss %.4f, train acc %.3f, test loss %.4f, '
              'test acc %.3f, time %.1f sec'
              % (epoch + 1, train_l_sum / len(train_iter), train_acc_sum / n, test_loss, 
                 test_acc, time.time() - start))
        #Save the best model
        if city == 'tal':
          if train_acc_sum>best_accuracy:
            torch.save(net.state_dict(),'most_accurate_tal.model')
            best_accuracy=test_acc
        elif "stir" in train_iter:
          if train_acc_sum>best_accuracy:
            torch.save(net.state_dict(),'most_accurate_stir.model')
            best_accuracy=test_acc
    return accuracy
def plot(hp):
  import matplotlib.pyplot as plt
  # %matplotlib inline

  # %config InlineBackend.figure_format = 'retina'


  plt.plot(accuracy, label=hp)

  plt.xlabel("Epochs")

  plt.ylabel("Accuracy")

  plt.legend(frameon=False)

# %%
# Write your codes for E1 here. Create more code cells if needed
# parameters: number of epochs, learning rate, 
# size of the batch, and weight decay lambda
num_epochs, lr, batch_size, wd_lambda, city = 2, 0.01, 20, 0.0001, 'tal'
# Based on AlexNet-5 (now using a network from the PyTorch Package!)
net = torchvision.models.alexnet()

# Sending model to device
net.to(device)
print(summary(net,(3,227,227))) # visualize number of parameters' net, output of each layer and total mega bytes necessary for forward pass
                                # and stored weights. 

# Cross-entropy loss
loss = nn.CrossEntropyLoss()

# loading dataset: mnist
train_loader_tal, test_loader_tal, train_loader_stir, test_loader_stir = load_data(batch_size, resize=227)

# optimizer setup
trainer = optim.SGD(net.parameters(), lr=lr, weight_decay=wd_lambda, momentum=0.9)

# training and validating via Pytorch
accuracy = train_validate(net, train_loader_tal, test_loader_tal, batch_size, trainer, loss, 
                num_epochs, city)
plot('lol')
num_epochs, lr, batch_size, wd_lambda, city = 2, 0.01, 20, 0.01, 'tal'
accuracy = train_validate(net, train_loader_tal, test_loader_tal, batch_size, trainer, loss, 
                num_epochs, city)
plot('kek')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 56, 56]          23,296
#               ReLU-2           [-1, 64, 56, 56]               0
#          MaxPool2d-3           [-1, 64, 27, 27]               0
#             Conv2d-4          [-1, 192, 27, 27]         307,392
#               ReLU-5          [-1, 192, 27, 27]               0
#          MaxPool2d-6          [-1, 192, 13, 13]               0
#             Conv2d-7          [-1, 384, 13, 13]         663,936
#               ReLU-8          [-1, 384, 13, 13]               0
#             Conv2d-9          [-1, 256, 13, 13]         884,992
#              ReLU-10          [-1, 256, 13, 13]               0
#            Conv2d-11          [-1, 256, 13, 13]         590,080
#              ReLU-12          [-1, 256, 13, 13]               0
#         MaxPool2d-13            [-1, 256, 6, 6]               0
# AdaptiveAvgPool2d-14            [-1, 256, 6, 6]               0
#           Dropout-15                 [-1, 9216]               0
#            Linear-16                 [-1, 4096]      37,752,832
#              ReLU-17                 [-1, 4096]               0
#           Dropout-18                 [-1, 4096]               0
#            Linear-19                 [-1, 4096]      16,781,312
#              ReLU-20                 [-1, 4096]               0
#            Linear-21                 [-1, 1000]       4,097,000
# ================================================================
# Total params: 61,100,840
# Trainable params: 61,100,840
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.59
# Forward/backward pass size (MB): 8.49
# Params size (MB): 233.08
# Estimated Total Size (MB): 242.16
# ----------------------------------------------------------------
# None
# training on cpu
# epoch 1, train loss 6.8399, train acc 0.515, test loss 6.6828, test acc 0.769, time 20.7 sec
# epoch 2, train loss 6.4179, train acc 0.769, test loss 5.6721, test acc 0.769, time 20.9 sec
# training on cpu
# epoch 1, train loss 3.4760, train acc 0.631, test loss 4.0550, test acc 0.231, time 20.8 sec
# epoch 2, train loss 2.2069, train acc 0.500, test loss 1.1180, test acc 0.769, time 19.9 sec

# %%
# Write your proposed solution code here. Create more code cells if you find it necessary

import matplotlib.pyplot as plt
import numpy as np

# Function to show the images
def imageshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# Function to test the model with a batch of images and show the labels predictions
def testBatch():
    # get batch of images from the test DataLoader  
    images, labels = next(iter(test_loader))

    # show all images as one image grid
    imageshow(torchvision.utils.make_grid(images))
   
    # Show the real labels on the screen 
    print('Real labels: ', ' '.join('%5s' % labels[j] 
                               for j in range(32)))
  
    # Let's see what if the model identifiers the  labels of those example
    outputs = net(images)
    
    # We got the probability for every 10 labels. The highest (max) probability should be correct label
    _, predicted = torch.max(outputs, 1)
    
    # Let's show the predicted labels on the screen to compare with the real ones
    print('Predicted: ', ' '.join('%5s' % predicted[j] 
                              for j in range(32)))

testBatch()
# Out:
# Real labels:  tensor(0) tensor(1) tensor(0) tensor(1) tensor(1) tensor(0) tensor(0) tensor(1) tensor(1) tensor(1) tensor(1) tensor(1) tensor(0) tensor(1) tensor(1) tensor(1) tensor(1) tensor(0) tensor(0) tensor(1) tensor(0) tensor(1) tensor(1) tensor(0) tensor(1) tensor(0) tensor(1) tensor(0) tensor(1) tensor(1) tensor(1) tensor(1)
# Predicted:  tensor(0) tensor(1) tensor(0) tensor(1) tensor(1) tensor(0) tensor(1) tensor(1) tensor(1) tensor(1) tensor(1) tensor(1) tensor(0) tensor(1) tensor(1) tensor(1) tensor(1) tensor(1) tensor(0) tensor(1) tensor(0) tensor(1) tensor(1) tensor(0) tensor(1) tensor(0) tensor(1) tensor(0) tensor(1) tensor(1) tensor(1) tensor(1)

# %% [markdown]
# ---
#
# # 6. **Experimental tests and evaluations**
#
#
# Here you must implement your code for training, testing and evaluating your solution. For this, the following code blocks (*E1*, *E2*, and *E3*) are mandatory:
#
#   - *E1* - Training the models. Implement code to call the dataloaders implemented for training your models.  Make routines to test different parameters of your models. Plot graphs that illustrate how parameters impact model training. Compare. Train and select a model for each city (A and B) and justify. You should use half (50%) of the samples from each dataset for training and leave the other half for testing (50%).
#
# [top](#scrollTo=4i5afvUbhmGo)

# %%
# Write your codes for E1 here. Create more code cells if needed
with torch.no_grad():
  model = net.to(device)
  model.load_state_dict(torch.load('most_accurate.model'))
  total_correct =0.0
  for inputs, labels in test_loader:
    lables = labels.to(device)
    outputs = model(inputs.to(device))
    output_idx = torch.argmax(outputs, dim=1)
    total_correct += sum(labels==output_idx)
    print(f'Accuracy: {(total_correct/130)*100}%')
# Out:
# Accuracy: 14.615385055541992%
# Accuracy: 27.69230842590332%
# Accuracy: 40.769229888916016%

# %%
def test_accuracy(model,test_iter,loss):
  test_acc, test_loss = evaluate_accuracy(test_iter, model, loss)
  print('test loss %.4f, '
              'test acc %.3f'
              % (test_loss, 
                 test_acc))
model = net.to(device)
model.load_state_dict(torch.load('most_accurate.model'))
test_accuracy(model,test_loader,loss)
# Out:
# test loss 0.5198, test acc 0.883

# %%
print(accuracy)
# Out:
# [0.5076923076923077, 0.7692307692307693, 0.6461538461538462, 0.5538461538461539, 0.7692307692307693, 0.7307692307692307, 0.7692307692307693, 0.7692307692307693, 0.7692307692307693, 0.7692307692307693]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %config InlineBackend.figure_format = 'retina'


plt.plot(accuracy, label='Training loss')

plt.xlabel("Epochs")

plt.ylabel("Accuracy")

plt.legend(frameon=False)

# %% [markdown]
#   - *E2* - Testing the models in the dataset. You must implement code routines to test the predictive ability of your models using half of each dataset intended for testing. **The model trained in city A must be tested in city A. The model trained in city B must be tested in city B.** Use the evaluation metrics (accuracy, F1-score, AUC, etc) that are most appropriate for your problem. Plot graphs that illustrate the results obtained for each city (A and B). Plot visual examples of correctly (true positive) and incorrectly (false positive) classified samples.
#
# [top](#scrollTo=4i5afvUbhmGo)

# %%
# Write your codes for E2 here. Create more code cells if needed

# %% [markdown]
# Validation dataset: The examples in the validation dataset are used to tune the hyperparameters, such as learning rate and epochs. The aim of creating a validation set is to avoid large overfitting of the model. It is a checkpoint to know if the model is fitted well with the training dataset.

# %% [markdown]
#   - *E3* - Testing the models crossing datasets. Here you must do exactly the same as in *E2*, but now training in one city and testing in the other. **The model trained in city A must be tested in city B. The model trained in city B must be tested in city A.** Use the same metrics and plot the same types of graphs so that results are comparable.
#
# [top](scrollTo=4i5afvUbhmGo)

# %%
# Write your codes for E3 here. Create more code cells if needed

# %% [markdown]
# https://learn.microsoft.com/en-us/windows/ai/windows-ml/tutorials/pytorch-train-model
# https://machinelearningmastery.com/save-and-load-your-pytorch-models/
# https://www.researchgate.net/figure/Comparison-of-AlexNet-and-ResNet-18_fig4_343955468

# %% [markdown]
# ---
#
# # 7. **Quiz and Report**
#
# Answer the assessment quiz that will be made available on Canvas one week before the final deadline. Make a 2-page report using the [IEEE template](https://www.overleaf.com/read/rdqwshtvyjdn) with a maximum of 1000 words. Latex is recommended, but you can deliver the report in MS Word if you prefer. Your report should contain five sections: introduction, description of the proposed solution with justifications, results (here you can include the same graphs and pictures generated in this jupyter notebook), discussion of the results, and conclusion. Properly cite references to articles, tutorials, and sources used. A pdf version of your report should be made available in the project's github repository under the name "[project name] + _final_report.pdf".
#
#
# [top](#scrollTo=4i5afvUbhmGo)
